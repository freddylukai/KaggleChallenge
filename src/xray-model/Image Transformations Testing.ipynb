# %%
import numpy as np
import utils
from scipy import ndimage
import matplotlib.pyplot as plt
# Out:
# C:\Users\deawari\AppData\Local\Continuum\conda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from scipy import misc

fig = plt.figure()
ax1 = fig.add_subplot(151)  
ax2 = fig.add_subplot(152)
ax3 = fig.add_subplot(153)
ax4 = fig.add_subplot(154)
ax5 = fig.add_subplot(155)

ascent = misc.ascent()
ax1.imshow(ascent)

angle = np.random.randint(0,45) 
print ("Angle: ",angle)
rotated = utils.rotate_image(ascent, angle)
ax2.imshow(rotated)

original_shape = ascent.shape  
height_shift = np.random.randint(0,original_shape[0]/10)
width_shift = np.random.randint(0, original_shape[1]/10)
print("Original Image shape: ", original_shape)
print('New shape: {0}, {1}'.format(height_shift, width_shift))
shifted = utils.shift_image(ascent, height_shift, width_shift)
ax3.imshow(shifted)

zoomed = utils.zoom_image(ascent,1.5, 1.5)
zoomedResized = np.zeros(ascent.shape)
height_small = min(zoomed.shape[0], ascent.shape[0])
width_small = min(zoomed.shape[1], ascent.shape[1])
zoomedResized= utils.crop_image(zoomed, height_small, width_small)
ax4.imshow(zoomedResized)

transformed = utils.transform_image(ascent)
ax5.imshow(transformed)
plt.show()
# Out:
# Angle:  0
# Original Image shape:  (512, 512)
# New shape: 3, 3
# Original Image shape:  (512, 512)
# New shape: 38, 13
# C:\Users\deawari\AppData\Local\Continuum\conda3\lib\site-packages\scipy\ndimage\interpolation.py:600: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
